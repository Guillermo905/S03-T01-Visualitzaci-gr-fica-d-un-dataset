# %% [markdown]
# # Exercici 1
#
# Descarrega el data set Airlines Delay: Airline on-time statistics and delay causes i carrega’l a un pandas Dataframe. Explora les dades que conté, i queda’t únicament amb les columnes que consideris rellevants.
#
# Es treballarà amb el dataframe sobre vols en EEUU durant el 2008 que conentenen les següents variables:
#
# * YEAR — Year in which flight took place
# * QUARTER — Quarter in which flight took place (1–4)
# * MONTH — Month in which flight took place (1–12)
# * DAY_OF_MONTH — Day of the month in which flight took place (1–31)
# * DAY_OF_WEEK — 1 for Monday, 2 for Tuesday,etc. in which flight took place
# * UNIQUE_CARRIER — Airline carrier code
# * TAIL_NUM — Aircraft tail number
# * FL_NUM — Flight number
# * ORIGIN_AIRPORT_ID — ID of origin airport
# * ORIGIN — Code of origin airport(ATL, DFW, SEA, etc.)
# * DEST_AIRPORT_ID — ID of destination airport
# * DEST — Code of destination airport (ATL, DFW, SEA, etc.)
# * CRS_DEP_TIME — Scheduled departure time
# * DEP_TIME — Actual departure time
# * DEP_DELAY — Departure Delay in minutes
# * DEP_DEL15 — 1 if departure is delayed by 15 minutes or more else 0
# * CRS_ARR_TIME — Scheduled arrival time
# * ARR_TIME — Actual arrival time
# * ARR_DELAY — Arrival Delay in minutes
# * ARR_DEL15 — 1 if arrived late by 15 minutes or more else 0
# * CANCELLED — 1 if Flight was cancelled else 0
# * DIVERTED — 1 if Flight was diverted else 0
# * CRS_ELAPSED_TIME — Scheduled flight time in minutes
# * ACTUAL_ELAPSED_TIME — Actual flight time in minutes
# * DISTANCE — Distance traveled in miles

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
vols = pd.read_csv("C:/Users/Guillermo/Desktop/Curs Data Scientist/Sprint 2/S02 T05 Exploració de les dades/DelayedFlights.csv")
#C:\Users\Guillermo\Desktop\Curs Data Scientist\Sprint 2\S02 T05 Exploració de les dades

# %%
vols.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
vols.shape
# Out:
# (1936758, 30)

# %%
vols.tail()
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
#          ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 1936753   1617.0        1552            DL  ...     9.0    18.0          0
# 1936754    904.0         749            DL  ...    15.0    34.0          0
# 1936755   1149.0        1010            DL  ...     8.0    32.0          0
# 1936756   1446.0        1437            DL  ...    13.0    13.0          0
# 1936757   1413.0        1418            DL  ...     8.0    11.0          0
#
# ...

# %%
vols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 30 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   Year               int64
#  2   Month              int64
#  3   DayofMonth         int64
#  4   DayOfWeek          int64
#  5   DepTime            float64
#  6   CRSDepTime         int64
#  7   ArrTime            float64
#  8   CRSArrTime         int64
#  9   UniqueCarrier      object
#  10  FlightNum          int64
#  11  TailNum            object
#  12  ActualElapsedTime  float64
#  13  CRSElapsedTime     float64
#  14  AirTime            float64
#  15  ArrDelay           float64
#  16  DepDelay           float64
#  17  Origin             object
#  18  Dest               object
#  19  Distance           int64
#  20  TaxiIn             float64
#  21  TaxiOut            float64
#  22  Cancelled          int64
#  23  CancellationCode   object
# ...

# %%
vols.isnull().sum()
# Out:
# Unnamed: 0                0
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                7110
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   5
# ActualElapsedTime      8387
# CRSElapsedTime          198
# AirTime                8387
# ArrDelay               8387
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# TaxiIn                 7110
# TaxiOut                 455
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         689270
# WeatherDelay         689270
# NASDelay             689270
# SecurityDelay        689270
# LateAircraftDelay    689270
# dtype: int64

# %%
vols.nunique()#mostra els diferents valors que pren cada variable
# Out:
# Unnamed: 0           1936758
# Year                       1
# Month                     12
# DayofMonth                31
# DayOfWeek                  7
# DepTime                 1438
# CRSDepTime              1207
# ArrTime                 1440
# CRSArrTime              1364
# UniqueCarrier             20
# FlightNum               7499
# TailNum                 5366
# ActualElapsedTime        673
# CRSElapsedTime           515
# AirTime                  650
# ArrDelay                1128
# DepDelay                1058
# Origin                   303
# Dest                     304
# Distance                1419
# TaxiIn                   180
# TaxiOut                  332
# Cancelled                  2
# CancellationCode           4
# Diverted                   2
# CarrierDelay             983
# WeatherDelay             599
# NASDelay                 574
# SecurityDelay            156
# LateAircraftDelay        564
# dtype: int64

# %% [markdown]
# Los vuelos todos pertenecen al año 2008. Las variables cualitativas son:
# * Year                       1
# * Month                     12
# * DayOfWeek                  7
# * UniqueCarrier             20
# * Origin                   303
# * Dest                     304
# * Cancelled                  2
# * CancellationCode           4
# * Diverted                   2

# %% [markdown]
# Se eliminarán aquellos datos que no presenten información útil para el análisis o bien presentan un número elevado de valores nulos como:
# * CarrierDelay         689270
# * WeatherDelay         689270
# * NASDelay             689270
# * SecurityDelay        689270
# * LateAircraftDelay    689270
#
# Todas estas variables presentan un 35.6% de valores nulos

# %%
 689270/1936758*100
# Out:
# 35.588855189961784

# %% [markdown]
# Por lo tanto se decide reducir el total de variables del dataframe en una primera selección de las que pueden ser más útiles.

# %%
vols2 = vols.drop(['Unnamed: 0', 'CancellationCode', 'Year', 'CarrierDelay', 'WeatherDelay',
                 'NASDelay', 'SecurityDelay', 'LateAircraftDelay' ], axis = 1)

# %%
vols2.info()#comprobamos la reducción de las variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 22 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Month              int64
#  1   DayofMonth         int64
#  2   DayOfWeek          int64
#  3   DepTime            float64
#  4   CRSDepTime         int64
#  5   ArrTime            float64
#  6   CRSArrTime         int64
#  7   UniqueCarrier      object
#  8   FlightNum          int64
#  9   TailNum            object
#  10  ActualElapsedTime  float64
#  11  CRSElapsedTime     float64
#  12  AirTime            float64
#  13  ArrDelay           float64
#  14  DepDelay           float64
#  15  Origin             object
#  16  Dest               object
#  17  Distance           int64
#  18  TaxiIn             float64
#  19  TaxiOut            float64
#  20  Cancelled          int64
#  21  Diverted           int64
# dtypes: float64(9), int64(9), object(4)
# memory usage: 325.1+ MB

# %%
vols2.head(10)
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0      1           3          4   2003.0        1955   2211.0        2225
# 1      1           3          4    754.0         735   1002.0        1000
# 2      1           3          4    628.0         620    804.0         750
# 3      1           3          4   1829.0        1755   1959.0        1925
# 4      1           3          4   1940.0        1915   2121.0        2110
# 5      1           3          4   1937.0        1830   2037.0        1940
# 6      1           3          4    706.0         700    916.0         915
# 7      1           3          4   1644.0        1510   1845.0        1725
# 8      1           3          4   1029.0        1020   1021.0        1010
# 9      1           3          4   1452.0        1425   1640.0        1625
#
#   UniqueCarrier  FlightNum TailNum  ...  AirTime  ArrDelay  DepDelay  Origin  \
# ...

# %% [markdown]
# TaxIn i TaxOut no vienen definidas pero se determina que son cuantitativas. Por el momento se decide guardar los datos por si acaso.

# %%
vols2.nunique() #Torna el número de valors que pot pendre la variable
# Out:
# Month                  12
# DayofMonth             31
# DayOfWeek               7
# DepTime              1438
# CRSDepTime           1207
# ArrTime              1440
# CRSArrTime           1364
# UniqueCarrier          20
# FlightNum            7499
# TailNum              5366
# ActualElapsedTime     673
# CRSElapsedTime        515
# AirTime               650
# ArrDelay             1128
# DepDelay             1058
# Origin                303
# Dest                  304
# Distance             1419
# TaxiIn                180
# TaxiOut               332
# Cancelled               2
# Diverted                2
# dtype: int64

# %%
vols2.ndim
# Out:
# 2

# %% [markdown]
# # Exercici 2
#
# Fes un informe complet del data set:.
#
# * Resumeix estadísticament les columnes d’interès
# * Troba quantes dades faltants hi ha per columna
# * Crea columnes noves (velocitat mitjana del vol, si ha arribat tard o no...)
# * Taula de les aerolínies amb més endarreriments acumulats
# * Quins són els vols més llargs? I els més endarrerits?
# * Etc.

# %% [markdown]
# __Resumen estadístico de las columnas__

# %%
# Se decide trabajar solo con los datos numéricos y mantener UniqueCarrier
volsNumber = vols2.drop(['Origin', 'Dest', 'TailNum', 'FlightNum'], axis = 1)

# %%
#media
volsNumber.mean(axis = 0)
#volsNumber.mean(axis = 0, skipna = True) s'obtenen els mateixos resultats ignorant NAs
# Out:
# Month                   6.111106
# DayofMonth             15.753470
# DayOfWeek               3.984827
# DepTime              1518.534117
# CRSDepTime           1467.472644
# ArrTime              1610.140629
# CRSArrTime           1634.224641
# ActualElapsedTime     133.305863
# CRSElapsedTime        134.302744
# AirTime               108.277147
# ArrDelay               42.199885
# DepDelay               43.185176
# Distance              765.686159
# TaxiIn                  6.812975
# TaxiOut                18.232203
# Cancelled               0.000327
# Diverted                0.004004
# dtype: float64

# %%
#Mediana
volsNumber.median(axis = 0)
# Out:
# Month                   6.0
# DayofMonth             16.0
# DayOfWeek               4.0
# DepTime              1545.0
# CRSDepTime           1510.0
# ArrTime              1715.0
# CRSArrTime           1705.0
# ActualElapsedTime     116.0
# CRSElapsedTime        116.0
# AirTime                90.0
# ArrDelay               24.0
# DepDelay               24.0
# Distance              606.0
# TaxiIn                  6.0
# TaxiOut                14.0
# Cancelled               0.0
# Diverted                0.0
# dtype: float64

# %%
#Desviacio estandar
volsNumber.std(axis = 0)
# Out:
# Month                  3.482546
# DayofMonth             8.776272
# DayOfWeek              1.995966
# DepTime              450.485255
# CRSDepTime           424.766800
# ArrTime              548.178143
# CRSArrTime           464.634712
# ActualElapsedTime     72.060069
# CRSElapsedTime        71.341439
# AirTime               68.642610
# ArrDelay              56.784715
# DepDelay              53.402502
# Distance             574.479653
# TaxiIn                 5.273595
# TaxiOut               14.338534
# Cancelled              0.018076
# Diverted               0.063147
# dtype: float64

# %%
#Cuartiles
#for name, colum in enumerate(volsNumber):
#    print(name, np.quantile(colum, 0.5))
    
    #np.quantile(volsNumber[colum], 0.5
quantil25 = np.nanpercentile(volsNumber, axis = 0, q = 25)
quantil75 = np.nanpercentile(volsNumber, axis = 0, q = 75)
colNames = volsNumber.columns.values

def quantilsNames(names, quantils25, quantils75 ):#Torna el quantil 25 i 75 
    print("Variable", "\t", "quantil 25", "\t", "quantil 75")
    for name, quantil25, quantil75 in zip(names, quantils25, quantils75):
        print(name, "\t", quantil25, "\t", quantil75)
        
quantilsNames(colNames, quantil25, quantil75)
# Out:
# Variable 	 quantil 25 	 quantil 75
# Month 	 3.0 	 9.0
# DayofMonth 	 8.0 	 23.0
# DayOfWeek 	 2.0 	 6.0
# DepTime 	 1203.0 	 1900.0
# CRSDepTime 	 1135.0 	 1815.0
# ArrTime 	 1316.0 	 2030.0
# CRSArrTime 	 1325.0 	 2014.0
# ActualElapsedTime 	 80.0 	 165.0
# CRSElapsedTime 	 82.0 	 165.0
# AirTime 	 58.0 	 137.0
# ArrDelay 	 9.0 	 56.0
# DepDelay 	 12.0 	 53.0
# Distance 	 338.0 	 998.0
# TaxiIn 	 4.0 	 8.0
# TaxiOut 	 10.0 	 21.0
# Cancelled 	 0.0 	 0.0
# Diverted 	 0.0 	 0.0

# %% [markdown]
# Aunque las horas se han de transformar previamente antes de hacer ningún análisis de los resultados obtenidos, se puede concluir que la mayoría de viajes se realizan en junio, mostrando una horquilla que va entre marzo y septiembre. Esto concuerda con los meses de vacaciones o cuando hace buen tiempo en el hemisferio norte.
#
# También se observa que prefieren viajar a mediados de mes, evitando los primeros o últimos días. El día de la semana que prefieren los estadounidenses para iniciar sus viajes es entre el martes y el sábado, siendo el día preferente el jueves y coincidiendo así con el fin de semana.
#
# La distancia que recorren los vuelos no presentan uniformidad debido a que la dispersión de los datos es elevada debido a su desviación estándar (765.69+- 574; mediana: 606) y la mayoría suelen salir por el mediodía y llegan a la tarde a su destino. Mostrando una mayor oferta, y probablemente un mayor interés del cliente, en no salir temprano y llegar a media tarde a su destino. El tiempo de vuelo medio es de 133 minutos con una desviación de 72 min. Por lo tanto, para los usuarios los viajes más habituales sulen ser de unas 2h aproximadamente.
#
# También se muestra que la mayoría de vuelos no presentan cancelaciones ni desviaciones

# %%
#Registros de NAs
volsNumber.isnull().sum()
# Out:
# Month                   0
# DayofMonth              0
# DayOfWeek               0
# DepTime                 0
# CRSDepTime              0
# ArrTime              7110
# CRSArrTime              0
# ActualElapsedTime    8387
# CRSElapsedTime        198
# AirTime              8387
# ArrDelay             8387
# DepDelay                0
# Distance                0
# TaxiIn               7110
# TaxiOut               455
# Cancelled               0
# Diverted                0
# dtype: int64

# %%
#Crea columnes noves (velocitat mitjana del vol, si ha arribat tard o no...)

#volsNumber['velocitat(milles/min)'] = (volsNumber['Distance'])/volsNumber['ActualElapsedTime']
volsNumber['velocitat (km/h)'] = round((volsNumber['Distance']*1.61)/(volsNumber['ActualElapsedTime']/60),2)
#1.61 passa milles a km i entre 60 a minuts

# %%
#volsNumber.pop('velocitat')#Elimna una columna de un df
volsNumber.head()
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0      1           3          4   2003.0        1955   2211.0        2225
# 1      1           3          4    754.0         735   1002.0        1000
# 2      1           3          4    628.0         620    804.0         750
# 3      1           3          4   1829.0        1755   1959.0        1925
# 4      1           3          4   1940.0        1915   2121.0        2110
#
#    ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  DepDelay  Distance  \
# 0              128.0           150.0    116.0     -14.0       8.0       810
# 1              128.0           145.0    113.0       2.0      19.0       810
# 2               96.0            90.0     76.0      14.0       8.0       515
# 3               90.0            90.0     77.0      34.0      34.0       515
# 4              101.0           115.0     87.0      11.0      25.0       688
#
#    TaxiIn  TaxiOut  Cancelled  Diverted  velocitat (km/h)
# ...

# %%
print(volsNumber['velocitat (km/h)'].mean(), "+-", volsNumber['velocitat (km/h)'].std())
print(volsNumber['velocitat (km/h)'].max(), volsNumber['velocitat (km/h)'].min())
# Out:
# 507.5158705508039 +- 145.3146608297548
# 2677.2 17.71

# %% [markdown]
# En la nova variable realitzada la velocitat mitja dels vols és de 507.5km/h $\pm$ 145.3, sent la velocitat màxima de 2677 km/h i la més baixa de 17.71km/h

# %%
#Obtindrem la informació del vol amb velocitat mínima
vols2[volsNumber['velocitat (km/h)']== 17.71]
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1310766      8          10          7   1315.0        1220   1415.0
#
#          CRSArrTime  FlightNum TailNum  ActualElapsedTime  ...  AirTime  \
# 1310766        1320       5572  N819CA               60.0  ...     14.0
#
#          ArrDelay  DepDelay  Origin Dest Distance  TaxiIn  TaxiOut  Cancelled  \
# 1310766      55.0      55.0     JFK  LGA       11     8.0     38.0          0
#
#          Diverted
# 1310766         0
#
# [1 rows x 21 columns]

# %% [markdown]
# El vuelo 5572 fue el más lento del todo el registro con una velocidad de 17.71km/h durante una hora de viaje para una distancia de 11 km. Si buscamos en el recorrido en el google maps podría tratarse de un error por su corto recorrido y el tiempo tardado. O bien, ha habido una anomalía en el desplazamiento debido a la cercanía de los dos lugares como se muestra en la siguiente imagen.
#
# ![imagen.png](attachment:imagen.png)

# %%
volsNumber.describe()
# Out:
#               Month    DayofMonth     DayOfWeek       DepTime    CRSDepTime  \
# count  1.936758e+06  1.936758e+06  1.936758e+06  1.936758e+06  1.936758e+06
# mean   6.111106e+00  1.575347e+01  3.984827e+00  1.518534e+03  1.467473e+03
# std    3.482546e+00  8.776272e+00  1.995966e+00  4.504853e+02  4.247668e+02
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    3.000000e+00  8.000000e+00  2.000000e+00  1.203000e+03  1.135000e+03
# 50%    6.000000e+00  1.600000e+01  4.000000e+00  1.545000e+03  1.510000e+03
# 75%    9.000000e+00  2.300000e+01  6.000000e+00  1.900000e+03  1.815000e+03
# max    1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03  2.359000e+03
#
#             ArrTime    CRSArrTime  ActualElapsedTime  CRSElapsedTime  \
# count  1.929648e+06  1.936758e+06       1.928371e+06    1.936560e+06
# mean   1.610141e+03  1.634225e+03       1.333059e+02    1.343027e+02
# std    5.481781e+02  4.646347e+02       7.206007e+01    7.134144e+01
# ...

# %%
volsNumber.pop('arribar30tard')
volsNumber.head()
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0      1           3          4   2003.0        1955   2211.0        2225
# 1      1           3          4    754.0         735   1002.0        1000
# 2      1           3          4    628.0         620    804.0         750
# 3      1           3          4   1829.0        1755   1959.0        1925
# 4      1           3          4   1940.0        1915   2121.0        2110
#
#    ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  DepDelay  Distance  \
# 0              128.0           150.0    116.0     -14.0       8.0       810
# 1              128.0           145.0    113.0       2.0      19.0       810
# 2               96.0            90.0     76.0      14.0       8.0       515
# 3               90.0            90.0     77.0      34.0      34.0       515
# 4              101.0           115.0     87.0      11.0      25.0       688
#
#    TaxiIn  TaxiOut  Cancelled  Diverted  velocitat (km/h)
# ...

# %%
#Si el vol h aarribat tard més de 30 minuts
#CRS_ARR_TIME — Scheduled arrival time
#ARR_TIME — Actual arrival time
#ARR_DELAY — Arrival Delay in minutes
#volsNumber['arribar30tard'] = 1 if [volsNumber['ArrDelay']>30] else 0
#volsNumber.head(30)
#if [volsNumber['ArrDelay']>=30.0]:
 #   volsNumber['arribar30tard'] = 1
#else:
#    volsNumber['arribar30tard'] = 0

#DA IGUAL COMO HAGAS EL IF, CONCEPTO TÍPICO NO FUNCIONA. Pero sí funciona con apply y lambda


volsNumber['arribar30tard']= volsNumber['ArrDelay'].apply(lambda x : True if x >= 30 else False)
#at_time a la hora; out_time amb retard
volsNumber.head(20)
# Out:
#     Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0       1           3          4   2003.0        1955   2211.0        2225
# 1       1           3          4    754.0         735   1002.0        1000
# 2       1           3          4    628.0         620    804.0         750
# 3       1           3          4   1829.0        1755   1959.0        1925
# 4       1           3          4   1940.0        1915   2121.0        2110
# 5       1           3          4   1937.0        1830   2037.0        1940
# 6       1           3          4    706.0         700    916.0         915
# 7       1           3          4   1644.0        1510   1845.0        1725
# 8       1           3          4   1029.0        1020   1021.0        1010
# 9       1           3          4   1452.0        1425   1640.0        1625
# 10      1           3          4    754.0         745    940.0         955
# ...

# %%
#Taula de les aerolínies amb més endarreriments acumulats
vols2.columns
vols.columns
taula = pd.crosstab(vols['UniqueCarrier'], volsNumber['arribar30tard'])
print(taula)
# Out:
# arribar30tard   False    True
# UniqueCarrier
# 9E              26692   25193
# AA              97387   94478
# AQ                577     173
# AS              23911   15382
# B6              26037   29278
# CO              58731   41464
# DL              67121   47117
# EV              42150   39727
# F9              19881    8388
# FL              39823   31461
# HA               5215    2275
# MQ              73745   68175
# NW              42663   36445
# OH              24463   28194
# OO              70582   61851
# UA              71821   69605
# US              59017   39408
# WN             253448  124154
# XE              51882   51781
# YV              30587   36476

# %% [markdown]
# Los retrasos también se muestran en las siguientes gráficas por aerolineas.

# %%
subsample = volsNumber.sample(frac = 0.05)

# %%
subsample.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime', 'ArrTime',
#        'CRSArrTime', 'UniqueCarrier', 'ActualElapsedTime', 'CRSElapsedTime',
#        'AirTime', 'ArrDelay', 'DepDelay', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'Diverted', 'arribar30tard'],
#       dtype='object')

# %%
sns.displot(data=subsample, x='ArrDelay', hue='UniqueCarrier',multiple = 'stack', palette='deep')

plt.xlim(-70,500)#El resta de dades son tan petites que no es graficaràn

plt.show()

# %%
sns.set()
sns.boxplot(data=subsample, x='UniqueCarrier', y='ArrDelay', palette='deep')
plt.rcParams['figure.figsize'] = [20, 5]
plt.show()

# %%
taula.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 9E to YV
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   False   20 non-null     int64
#  1   True    20 non-null     int64
# dtypes: int64(2)
# memory usage: 480.0+ bytes

# %%
taula['%Delay']= round((taula[True]/(taula[False]+taula[True])*100),2)
print(taula)
# Out:
# arribar30tard   False    True  %Delay
# UniqueCarrier
# 9E              26692   25193   48.56
# AA              97387   94478   49.24
# AQ                577     173   23.07
# AS              23911   15382   39.15
# B6              26037   29278   52.93
# CO              58731   41464   41.38
# DL              67121   47117   41.24
# EV              42150   39727   48.52
# F9              19881    8388   29.67
# FL              39823   31461   44.13
# HA               5215    2275   30.37
# MQ              73745   68175   48.04
# NW              42663   36445   46.07
# OH              24463   28194   53.54
# OO              70582   61851   46.70
# UA              71821   69605   49.22
# US              59017   39408   40.04
# WN             253448  124154   32.88
# XE              51882   51781   49.95
# YV              30587   36476   54.39

# %% [markdown]
# De la tabla anterior se concluye que prácticamente todas las aerolineas sufren retraso superiores al 40% en los vuelos realizados en el año 2008.
#
# A continuación se comprobará en qué aeropuertos de salida se producen los vuelos que llegan tarde a su destino conjuntamente con las aerolineas en una tabla pivote o tabla dinámica.

# %%
vols['arribar30tard'] = volsNumber['arribar30tard']
vols.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay',
#        'arribar30tard'],
#       dtype='object')

# %%
#tableAirpot = pd.pivot_table(vols, values = 'Origin', index = 'UniqueCarrier', aggfunc = np.sum)
tableAirpot = vols.pivot_table('arribar30tard', 'Origin', 'UniqueCarrier')

# %%
print(tableAirpot)
# Out:
# UniqueCarrier        9E        AA  AQ        AS        B6        CO        DL  \
# Origin
# ABE            0.486842       NaN NaN       NaN       NaN       NaN       NaN
# ABI                 NaN       NaN NaN       NaN       NaN       NaN       NaN
# ABQ                 NaN  0.494993 NaN       NaN       NaN  0.439189  0.325103
# ABY                 NaN       NaN NaN       NaN       NaN       NaN       NaN
# ACK                 NaN       NaN NaN       NaN  0.674419       NaN       NaN
# ...                 ...       ...  ..       ...       ...       ...       ...
# WYS                 NaN       NaN NaN       NaN       NaN       NaN       NaN
# XNA            0.488532  0.555556 NaN       NaN       NaN       NaN       NaN
# YAK                 NaN       NaN NaN  0.544554       NaN       NaN       NaN
# YKM                 NaN       NaN NaN       NaN       NaN       NaN       NaN
# YUM                 NaN       NaN NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
#pd.options.display.max_rows = 20 opción que elimina el límite de filas a ver en el data frame, para ver los 
#de cada compañia se va hacer la media de cada columna
np.mean(tableAirpot, axis = 0)#mitja de cada aerolinea de vols amb retard en relació de cada aeroport
# Out:
# UniqueCarrier
# 9E    0.488784
# AA    0.489030
# AQ    0.207024
# AS    0.405482
# B6    0.529788
# CO    0.445041
# DL    0.435218
# EV    0.499956
# F9    0.296576
# FL    0.436219
# HA    0.377402
# MQ    0.505430
# NW    0.459332
# OH    0.559897
# OO    0.474933
# UA    0.487377
# US    0.389179
# WN    0.340463
# XE    0.513585
# YV    0.544313
# dtype: float64

# %% [markdown]
# En la tabla anterior se muestra la media de retrasos producidos en cada aeropuerto para cada aerolinea. En consecuencia, ahora convendría analizar estadísticamente, por ejemplo a través de una ANOVA verificando previamente si los datos presentan una distribución normal y homocedasticidad, la posible presencia de diferencias estadísticamente significativas entre la media obtenida para cada aerolinea entre los diferentes aeropuertos en los que opera. Esto permitiría comprobar si hay diferencias entre la gestión de los aeropuertos. Ya que esto significaría que la gestión de los aeropuertos afecta a los retrasos de más de media hora sufrídos por las aerolíneas. Sin embargo, este análisis no se va a llevar a cabo ya que extralímita lo solicitado en el ejercicio.
#
# Por otro lado, también sería conveniente hacer este análisis con los aeropuertos de llegada o bien si había diferencias entre la hora de salida con la programada y los mismo con las horas de llegada.

# %% [markdown]
# __Quins són els vols més llargs? I els més endarrerits?__

# %% [markdown]
# Para conocer cuales son los vuelos más largos primero se estudiará la mediana de la distancia de todos los vuelos. Se ha decidido en este caso la mediana, en vez de la media, porque es un estadístico más robusto a los valores extremos y nos da una idea de la centralidad de esta. En consecuencia, se considerará como vuelos más largos aquellos que superen el máximo intercuartílico.

# %%
np.median(volsNumber['Distance'])
# Out:
# 606.0

# %%
np.nanpercentile(volsNumber['Distance'], axis = 0, q = 75)
# Out:
# 998.0

# %%
sns.set()
sns.boxplot(data=subsample, x='UniqueCarrier', y='Distance', palette='deep')
plt.show()

# %% [markdown]
# De las medianas se extrae que la mayoría de vuelos suelen recorrer más distancias largas que cortas. Siendo esto muy pronunciado en HA y AQ.

# %%
vols2.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime', 'ArrTime',
#        'CRSArrTime', 'FlightNum', 'TailNum', 'ActualElapsedTime',
#        'CRSElapsedTime', 'AirTime', 'ArrDelay', 'DepDelay', 'Origin', 'Dest',
#        'Distance', 'TaxiIn', 'TaxiOut', 'Cancelled', 'Diverted'],
#       dtype='object')

# %%
vols2['vol_llarg'] = vols2['Distance'].apply(lambda x: True if x > 998 else False)

# %%
vols2.head(20)
# Out:
#     Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0       1           3          4   2003.0        1955   2211.0        2225
# 1       1           3          4    754.0         735   1002.0        1000
# 2       1           3          4    628.0         620    804.0         750
# 3       1           3          4   1829.0        1755   1959.0        1925
# 4       1           3          4   1940.0        1915   2121.0        2110
# 5       1           3          4   1937.0        1830   2037.0        1940
# 6       1           3          4    706.0         700    916.0         915
# 7       1           3          4   1644.0        1510   1845.0        1725
# 8       1           3          4   1029.0        1020   1021.0        1010
# 9       1           3          4   1452.0        1425   1640.0        1625
# 10      1           3          4    754.0         745    940.0         955
# ...

# %%
# Ahora pasamos a contar los vuelos más largos
#vols2[vols2['vol_llarg'] == True].count(). Mucho más eficiente la siguiente manera
np.sum(vols2['vol_llarg'] == True)
# Out:
# 482523

# %% [markdown]
# Como hay 482523 no se van a mostrar los números de vuelo que es lo que solicitaba la pregunta.
#
# Para conocer el número total de vuelos más atrasados se van a comprobar todos los vuelos que han llegado con un retraso superior a 30 minutos.

# %%
volsNumber.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime', 'ArrTime',
#        'CRSArrTime', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime',
#        'ArrDelay', 'DepDelay', 'Distance', 'TaxiIn', 'TaxiOut', 'Cancelled',
#        'Diverted', 'arribar30tard'],
#       dtype='object')

# %%
np.sum(volsNumber['arribar30tard']== True)
# Out:
# 851025

# %% [markdown]
# Al igual que en el caso anterior no se van a mostrar el nombre de los vuelos debido a su gran cantidad. Pero se mostrarán en el siguiente gráfico

# %%
#sns.set()
y=[volsNumber['arribar30tard'].sum(), volsNumber['arribar30tard'].count()-volsNumber['arribar30tard'].sum()]
x=['True', 'False']
sns.barplot(x=x, y=y)

plt.title('Número de retards superiors a 30 minuts')
plt.show()

# %% [markdown]
# ## Extras
#
#
#
# Comparar aeropuertos y llegadas y salidas en relación a sus horas programadas

# %%
taula_cancel= pd.crosstab(vols['UniqueCarrier'], vols['Cancelled'])
print(taula_cancel)
# Out:
# Cancelled           0    1
# UniqueCarrier
# 9E              51827   58
# AA             191819   46
# AQ                750    0
# AS              39282   11
# B6              55305   10
# CO             100157   38
# DL             114217   21
# EV              81848   29
# F9              28267    2
# FL              71277    7
# HA               7487    3
# MQ             141816  104
# NW              79092   16
# OH              52645   12
# OO             132344   89
# UA             141379   47
# US              98399   26
# WN             377587   15
# XE             103617   46
# YV              67010   53

# %%
taula_cancel.columns
# Out:
# Int64Index([0, 1], dtype='int64', name='Cancelled')

# %%
taula_cancel['%cancel'] = round(taula_cancel[1]/(taula_cancel[1]+taula_cancel[0])*100,3)

# %%
print(taula_cancel)
# Out:
# Cancelled           0    1  %cancel
# UniqueCarrier
# 9E              51827   58    0.112
# AA             191819   46    0.024
# AQ                750    0    0.000
# AS              39282   11    0.028
# B6              55305   10    0.018
# CO             100157   38    0.038
# DL             114217   21    0.018
# EV              81848   29    0.035
# F9              28267    2    0.007
# FL              71277    7    0.010
# HA               7487    3    0.040
# MQ             141816  104    0.073
# NW              79092   16    0.020
# OH              52645   12    0.023
# OO             132344   89    0.067
# UA             141379   47    0.033
# US              98399   26    0.026
# WN             377587   15    0.004
# XE             103617   46    0.044
# YV              67010   53    0.079

# %% [markdown]
# En valores relativos quien ha sufrido más retrasos es la compañia 9E, mientras que en valores absolutos quien ha sufrido más retrasos ha sido MQ.

# %% [markdown]
# ## Exercici 3
#
# Exporta el data set net i amb les noves columnes a Excel.

# %% [markdown]
# Como se han utilizado tanto el dataset vols2, volsNumber y la variable 'UniqueCarrier' se van a juntar todos estos en un solo dataset

# %%
vols2.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime', 'ArrTime',
#        'CRSArrTime', 'FlightNum', 'TailNum', 'ActualElapsedTime',
#        'CRSElapsedTime', 'AirTime', 'ArrDelay', 'DepDelay', 'Origin', 'Dest',
#        'Distance', 'TaxiIn', 'TaxiOut', 'Cancelled', 'Diverted'],
#       dtype='object')

# %%
volsNumber.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime', 'ArrTime',
#        'CRSArrTime', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime',
#        'ArrDelay', 'DepDelay', 'Distance', 'TaxiIn', 'TaxiOut', 'Cancelled',
#        'Diverted', 'velocitat (km/h)', 'arribar30tard'],
#       dtype='object')

# %%
vols2['velocitat (km/h)'], vols2['arribar30tard'] = volsNumber['velocitat (km/h)'], volsNumber['arribar30tard']

# %%
vols2.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime', 'ArrTime',
#        'CRSArrTime', 'FlightNum', 'TailNum', 'ActualElapsedTime',
#        'CRSElapsedTime', 'AirTime', 'ArrDelay', 'DepDelay', 'Origin', 'Dest',
#        'Distance', 'TaxiIn', 'TaxiOut', 'Cancelled', 'Diverted',
#        'velocitat (km/h)', 'arribar30tard'],
#       dtype='object')

# %%
vols2.to_csv("Desktop/Curs Data Scientist/Sprint 2/vols2.csv")
